# %%
# import os
# from PIL import Image

# def check_image_dimensions(folder_name, target_width=227, target_height=227):
#     # Get the current working directory
#     cwd = os.getcwd()

#     # Combine the current working directory with the provided folder name
#     folder_path = os.path.join(cwd, folder_name)

#     # Loop through all files in the folder
#     for filename in os.listdir(folder_path):
#         # Check if the file is an image
#         if filename.endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
#             # Open the image
#             image_path = os.path.join(folder_path, filename)
#             image = Image.open(image_path)
#             width, height = image.size

#             # Check if the image dimensions match the target dimensions
#             if width != target_width or height != target_height:
#                 print(f"The image {filename} does not have the required dimensions (227x227).")
#                 print(f"Current dimensions: {width}x{height}")
#             else:
#                 print(f"The image {filename} has the correct dimensions (227x227).")


import os
from PIL import Image

def check_image_dimensions(folder_path, target_width=227, target_height=227):
    # Loop through all files in the folder
    for filename in os.listdir(folder_path):
        # Check if the file is an image
        if filename.endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            # Open the image
            image_path = os.path.join(folder_path, filename)
            image = Image.open(image_path)
            width, height = image.size

            # Check if the image dimensions match the target dimensions
            if width != target_width or height != target_height:
                print(f"The image {filename} does not have the required dimensions (227x227).")
                print(f"Current dimensions: {width}x{height}")
            else:
                print(f"The image {filename} has the correct dimensions (227x227).")

# Example usage:
folder_path = r"output_images/"  # Specify the folder path containing images
check_image_dimensions(folder_path)
# Out:
# The image Tr-glTr_0000_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0000_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0000_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0000_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0001_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0001_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0001_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0001_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0002_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0002_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0002_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0002_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0003_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0003_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0003_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0003_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0004_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0004_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0004_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0004_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0005_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0005_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0005_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0005_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0006_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0006_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0006_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0006_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0007_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0007_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0007_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0007_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0008_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0008_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0008_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0008_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0009_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0009_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0009_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-glTr_0009_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0010_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0010_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0010_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0010_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0011_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0011_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0011_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0011_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0012_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0012_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0012_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0012_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0013_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0013_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0013_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0013_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0014_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0014_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0014_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0014_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0015_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0015_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0015_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0015_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0016_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0016_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0016_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0016_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0017_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0017_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0017_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0017_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0018_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0018_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0018_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0018_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0019_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0019_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0019_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0019_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0020_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0020_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0020_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0020_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0021_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0021_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0021_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0021_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0022_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0022_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0022_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0022_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0023_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0023_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0023_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0023_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0024_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0024_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0024_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0024_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0025_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0025_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0025_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0025_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0026_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0026_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0026_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0026_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0027_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0027_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0027_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0027_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0028_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0028_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0028_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0028_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0029_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0029_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0029_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0029_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0030_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0030_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0030_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0030_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0031_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0031_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0031_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0031_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0032_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0032_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0032_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0032_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0033_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0033_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0033_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0033_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0034_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0034_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0034_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0034_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0035_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0035_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0035_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0035_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0036_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0036_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0036_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0036_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0037_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0037_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0037_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0037_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0038_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0038_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0038_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0038_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0039_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0039_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0039_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0039_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0040_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0040_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0040_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0040_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0041_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0041_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0041_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0041_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0042_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0042_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0042_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0042_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0043_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0043_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0043_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0043_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0044_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0044_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0044_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0044_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0045_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0045_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0045_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0045_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0046_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0046_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0046_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0046_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0047_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0047_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0047_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0047_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0048_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0048_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0048_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0048_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0049_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0049_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0049_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0049_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0050_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0050_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0050_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0050_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0051_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0051_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0051_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0051_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0052_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0052_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0052_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0052_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0053_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0053_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0053_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0053_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0054_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0054_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0054_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0054_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0055_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0055_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0055_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0055_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0056_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0056_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0056_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0056_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_0057_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_0057_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_0057_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0057_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_
rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_0153_rotated_90.jpg has the correct dimensions (227x227).
# ...
# The image Tr-gl_1041_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1042_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1042_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1042_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1042_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1043_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1043_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1043_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1043_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1044_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1044_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1044_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1044_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1045_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1045_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1045_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1045_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1046_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1046_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1046_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1046_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1047_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1047_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1047_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1047_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1048_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1048_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1048_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1048_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1049_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1049_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1049_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1049_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1050_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1050_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1050_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1050_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1051_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1051_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1051_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1051_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1052_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1052_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1052_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1052_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1053_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1053_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1053_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1053_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1054_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1054_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1054_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1054_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1055_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1055_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1055_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1055_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1056_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1056_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1056_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1056_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1057_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1057_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1057_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1057_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1058_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1058_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1058_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1058_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1059_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1059_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1059_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1059_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1060_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1060_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1060_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1060_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1061_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1061_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1061_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1061_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1062_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1062_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1062_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1062_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1063_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1063_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1063_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1063_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1064_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1064_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1064_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1064_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1065_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1065_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1065_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1065_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1066_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1066_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1066_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1066_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1067_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1067_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1067_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1067_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1068_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1068_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1068_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1068_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1069_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1069_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1069_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1069_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1070_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1070_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1070_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1070_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1071_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1071_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1071_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1071_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1072_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1072_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1072_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1072_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1073_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1073_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1073_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1073_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1074_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1074_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1074_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1074_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1075_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1075_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1075_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1075_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1076_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1076_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1076_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1076_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1077_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1077_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1077_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1077_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1078_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1078_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1078_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1078_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1079_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1079_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1079_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1079_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1080_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1080_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1080_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1080_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1081_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1081_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1081_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1081_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1082_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1082_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1082_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1082_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1083_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1083_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1083_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1083_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1084_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1084_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1084_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1084_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1085_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1085_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1085_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1085_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1086_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1086_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1086_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1086_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1087_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1087_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1087_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1087_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1088_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1088_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1088_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1088_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1089_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1089_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1089_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1089_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1090_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1090_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1090_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1090_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1091_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1091_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1091_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1091_rotated_90.jpg has the correct dimensions (227x227).
# The image Tr-gl_1092_flipped_horizontal.jpg has the correct dimensions (227x227).
# The image Tr-gl_1092_flipped_vertical.jpg has the correct dimensions (227x227).
# The image Tr-gl_1092_rotated_180.jpg has the correct dimensions (227x227).
# The image Tr-gl_1092_rotated_90.jpg has the correct dimensions (227x227).

# %%
curr=os.getcwd()
print(curr)
# Out:
# D:\RESEARCH D

# %%
import os

def check_folder_permissions(folder_path):
    if os.access(folder_path, os.R_OK):
        print(f"Read permission is granted on folder: {folder_path}")
    else:
        print(f"Read permission is NOT granted on folder: {folder_path}")

    if os.access(folder_path, os.W_OK):
        print(f"Write permission is granted on folder: {folder_path}")
    else:
        print(f"Write permission is NOT granted on folder: {folder_path}")

    if os.access(folder_path, os.X_OK):
        print(f"Execute permission is granted on folder: {folder_path}")
    else:
        print(f"Execute permission is NOT granted on folder: {folder_path}")

# Example usage
folder_path = "output_images"  # Specify the folder path you want to check permissions for
check_folder_permissions(folder_path)
# Out:
# Read permission is granted on folder: output_images
# Write permission is granted on folder: output_images
# Execute permission is granted on folder: output_images

# %%
def count_images_in_folder(folder_path):
    image_extensions = ('.jpg', '.png', '.jpeg')
    num_images = sum(1 for filename in os.listdir(folder_path) if filename.endswith(image_extensions))
    return num_images
num_images = count_images_in_folder(folder_path)
print(f"Number of images in '{folder_path}': {num_images}")
# Out:
# Number of images in 'output_images': 4372
