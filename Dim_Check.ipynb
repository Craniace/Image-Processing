# %%
# import os
# from PIL import Image

# def check_image_dimensions(folder_name, target_width=227, target_height=227):
#     # Get the current working directory
#     cwd = os.getcwd()

#     # Combine the current working directory with the provided folder name
#     folder_path = os.path.join(cwd, folder_name)

#     # Loop through all files in the folder
#     for filename in os.listdir(folder_path):
#         # Check if the file is an image
#         if filename.endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
#             # Open the image
#             image_path = os.path.join(folder_path, filename)
#             image = Image.open(image_path)
#             width, height = image.size

#             # Check if the image dimensions match the target dimensions
#             if width != target_width or height != target_height:
#                 print(f"The image {filename} does not have the required dimensions (227x227).")
#                 print(f"Current dimensions: {width}x{height}")
#             else:
#                 print(f"The image {filename} has the correct dimensions (227x227).")


import os
from PIL import Image

def check_image_dimensions(folder_path, target_width=227, target_height=227):
    # Loop through all files in the folder
    for filename in os.listdir(folder_path):
        # Check if the file is an image
        if filename.endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            # Open the image
            image_path = os.path.join(folder_path, filename)
            image = Image.open(image_path)
            width, height = image.size

            # Check if the image dimensions match the target dimensions
            if width != target_width or height != target_height:
                print(f"The image {filename} does not have the required dimensions (227x227).")
                print(f"Current dimensions: {width}x{height}")
            else:
                print(f"The image {filename} has the correct dimensions (227x227).")

# Example usage:
folder_path = r"new archive\Testing\ASPECT RATIO\new glioma"  # Specify the folder path containing images
check_image_dimensions(folder_path)
# Out:
# The image Te-glTr_0000.jpg has the correct dimensions (227x227).
# The image Te-glTr_0001.jpg has the correct dimensions (227x227).
# The image Te-glTr_0002.jpg has the correct dimensions (227x227).
# The image Te-glTr_0003.jpg has the correct dimensions (227x227).
# The image Te-glTr_0004.jpg has the correct dimensions (227x227).
# The image Te-glTr_0005.jpg has the correct dimensions (227x227).
# The image Te-glTr_0006.jpg has the correct dimensions (227x227).
# The image Te-glTr_0007.jpg has the correct dimensions (227x227).
# The image Te-glTr_0008.jpg has the correct dimensions (227x227).
# The image Te-glTr_0009.jpg has the correct dimensions (227x227).
# The image Te-gl_0010.jpg has the correct dimensions (227x227).
# The image Te-gl_0011.jpg has the correct dimensions (227x227).
# The image Te-gl_0012.jpg has the correct dimensions (227x227).
# The image Te-gl_0013.jpg has the correct dimensions (227x227).
# The image Te-gl_0014.jpg has the correct dimensions (227x227).
# The image Te-gl_0015.jpg has the correct dimensions (227x227).
# The image Te-gl_0016.jpg has the correct dimensions (227x227).
# The image Te-gl_0017.jpg has the correct dimensions (227x227).
# The image Te-gl_0018.jpg has the correct dimensions (227x227).
# The image Te-gl_0019.jpg has the correct dimensions (227x227).
# The image Te-gl_0020.jpg has the correct dimensions (227x227).
# The image Te-gl_0021.jpg has the correct dimensions (227x227).
# The image Te-gl_0022.jpg has the correct dimensions (227x227).
# The image Te-gl_0023.jpg has the correct dimensions (227x227).
# The image Te-gl_0024.jpg has the correct dimensions (227x227).
# The image Te-gl_0025.jpg has the correct dimensions (227x227).
# The image Te-gl_0026.jpg has the correct dimensions (227x227).
# The image Te-gl_0027.jpg has the correct dimensions (227x227).
# The image Te-gl_0028.jpg has the correct dimensions (227x227).
# The image Te-gl_0029.jpg has the correct dimensions (227x227).
# The image Te-gl_0030.jpg has the correct dimensions (227x227).
# The image Te-gl_0031.jpg has the correct dimensions (227x227).
# The image Te-gl_0032.jpg has the correct dimensions (227x227).
# The image Te-gl_0033.jpg has the correct dimensions (227x227).
# The image Te-gl_0034.jpg has the correct dimensions (227x227).
# The image Te-gl_0035.jpg has the correct dimensions (227x227).
# The image Te-gl_0036.jpg has the correct dimensions (227x227).
# The image Te-gl_0037.jpg has the correct dimensions (227x227).
# The image Te-gl_0038.jpg has the correct dimensions (227x227).
# The image Te-gl_0039.jpg has the correct dimensions (227x227).
# The image Te-gl_0040.jpg has the correct dimensions (227x227).
# The image Te-gl_0041.jpg has the correct dimensions (227x227).
# The image Te-gl_0042.jpg has the correct dimensions (227x227).
# The image Te-gl_0043.jpg has the correct dimensions (227x227).
# The image Te-gl_0044.jpg has the correct dimensions (227x227).
# The image Te-gl_0045.jpg has the correct dimensions (227x227).
# The image Te-gl_0046.jpg has the correct dimensions (227x227).
# The image Te-gl_0047.jpg has the correct dimensions (227x227).
# The image Te-gl_0048.jpg has the correct dimensions (227x227).
# The image Te-gl_0049.jpg has the correct dimensions (227x227).
# The image Te-gl_0050.jpg has the correct dimensions (227x227).
# The image Te-gl_0051.jpg has the correct dimensions (227x227).
# The image Te-gl_0052.jpg has the correct dimensions (227x227).
# The image Te-gl_0053.jpg has the correct dimensions (227x227).
# The image Te-gl_0054.jpg has the correct dimensions (227x227).
# The image Te-gl_0055.jpg has the correct dimensions (227x227).
# The image Te-gl_0056.jpg has the correct dimensions (227x227).
# The image Te-gl_0057.jpg has the correct dimensions (227x227).
# The image Te-gl_0058.jpg has the correct dimensions (227x227).
# The image Te-gl_0059.jpg has the correct dimensions (227x227).
# The image Te-gl_0060.jpg has the correct dimensions (227x227).
# The image Te-gl_0061.jpg has the correct dimensions (227x227).
# The image Te-gl_0062.jpg has the correct dimensions (227x227).
# The image Te-gl_0063.jpg has the correct dimensions (227x227).
# The image Te-gl_0064.jpg has the correct dimensions (227x227).
# The image Te-gl_0065.jpg has the correct dimensions (227x227).
# The image Te-gl_0066.jpg has the correct dimensions (227x227).
# The image Te-gl_0067.jpg has the correct dimensions (227x227).
# The image Te-gl_0068.jpg has the correct dimensions (227x227).
# The image Te-gl_0069.jpg has the correct dimensions (227x227).
# The image Te-gl_0070.jpg has the correct dimensions (227x227).
# The image Te-gl_0071.jpg has the correct dimensions (227x227).
# The image Te-gl_0072.jpg has the correct dimensions (227x227).
# The image Te-gl_0073.jpg has the correct dimensions (227x227).
# The image Te-gl_0074.jpg has the correct dimensions (227x227).
# The image Te-gl_0075.jpg has the correct dimensions (227x227).
# The image Te-gl_0076.jpg has the correct dimensions (227x227).
# The image Te-gl_0077.jpg has the correct dimensions (227x227).
# The image Te-gl_0078.jpg has the correct dimensions (227x227).
# The image Te-gl_0079.jpg has the correct dimensions (227x227).
# The image Te-gl_0080.jpg has the correct dimensions (227x227).
# The image Te-gl_0081.jpg has the correct dimensions (227x227).
# The image Te-gl_0082.jpg has the correct dimensions (227x227).
# The image Te-gl_0083.jpg has the correct dimensions (227x227).
# The image Te-gl_0084.jpg has the correct dimensions (227x227).
# The image Te-gl_0085.jpg has the correct dimensions (227x227).
# The image Te-gl_0086.jpg has the correct dimensions (227x227).
# The image Te-gl_0087.jpg has the correct dimensions (227x227).
# The image Te-gl_0088.jpg has the correct dimensions (227x227).
# The image Te-gl_0089.jpg has the correct dimensions (227x227).
# The image Te-gl_0090.jpg has the correct dimensions (227x227).
# The image Te-gl_0091.jpg has the correct dimensions (227x227).
# The image Te-gl_0092.jpg has the correct dimensions (227x227).
# The image Te-gl_0093.jpg has the correct dimensions (227x227).
# The image Te-gl_0094.jpg has the correct dimensions (227x227).
# The image Te-gl_0095.jpg has the correct dimensions (227x227).
# The image Te-gl_0096.jpg has the correct dimensions (227x227).
# The image Te-gl_0097.jpg has the correct dimensions (227x227).
# The image Te-gl_0098.jpg has the correct dimensions (227x227).
# The image Te-gl_0099.jpg has the correct dimensions (227x227).
# The image Te-gl_0100.jpg has the correct dimensions (227x227).
# The image Te-gl_0101.jpg has the correct dimensions (227x227).
# The image Te-gl_0102.jpg has the correct dimensions (227x227).
# The image Te-gl_0103.jpg has the correct dimensions (227x227).
# The image Te-gl_0104.jpg has the correct dimensions (227x227).
# The image Te-gl_0105.jpg has the correct dimensions (227x227).
# The image Te-gl_0106.jpg has the correct dimensions (227x227).
# The image Te-gl_0107.jpg has the correct dimensions (227x227).
# The image Te-gl_0108.jpg has the correct dimensions (227x227).
# The image Te-gl_0109.jpg has the correct dimensions (227x227).
# The image Te-gl_0110.jpg has the correct dimensions (227x227).
# The image Te-gl_0111.jpg has the correct dimensions (227x227).
# The image Te-gl_0112.jpg has the correct dimensions (227x227).
# The image Te-gl_0113.jpg has the correct dimensions (227x227).
# The image Te-gl_0114.jpg has the correct dimensions (227x227).
# The image Te-gl_0115.jpg has the correct dimensions (227x227).
# The image Te-gl_0116.jpg has the correct dimensions (227x227).
# The image Te-gl_0117.jpg has the correct dimensions (227x227).
# The image Te-gl_0118.jpg has the correct dimensions (227x227).
# The image Te-gl_0119.jpg has the correct dimensions (227x227).
# The image Te-gl_0120.jpg has the correct dimensions (227x227).
# The image Te-gl_0121.jpg has the correct dimensions (227x227).
# The image Te-gl_0122.jpg has the correct dimensions (227x227).
# The image Te-gl_0123.jpg has the correct dimensions (227x227).
# The image Te-gl_0124.jpg has the correct dimensions (227x227).
# The image Te-gl_0125.jpg has the correct dimensions (227x227).
# The image Te-gl_0126.jpg has the correct dimensions (227x227).
# The image Te-gl_0127.jpg has the correct dimensions (227x227).
# The image Te-gl_0128.jpg has the correct dimensions (227x227).
# The image Te-gl_0129.jpg has the correct dimensions (227x227).
# The image Te-gl_0130.jpg has the correct dimensions (227x227).
# The image Te-gl_0131.jpg has the correct dimensions (227x227).
# The image Te-gl_0132.jpg has the correct dimensions (227x227).
# The image Te-gl_0133.jpg has the correct dimensions (227x227).
# The image Te-gl_0134.jpg has the correct dimensions (227x227).
# The image Te-gl_0135.jpg has the correct dimensions (227x227).
# The image Te-gl_0136.jpg has the correct dimensions (227x227).
# The image Te-gl_0137.jpg has the correct dimensions (227x227).
# The image Te-gl_0138.jpg has the correct dimensions (227x227).
# The image Te-gl_0139.jpg has the correct dimensions (227x227).
# The image Te-gl_0140.jpg has the correct dimensions (227x227).
# The image Te-gl_0141.jpg has the correct dimensions (227x227).
# The image Te-gl_0142.jpg has the correct dimensions (227x227).
# The image Te-gl_0143.jpg has the correct dimensions (227x227).
# The image Te-gl_0144.jpg has the correct dimensions (227x227).
# The image Te-gl_0145.jpg has the correct dimensions (227x227).
# The image Te-gl_0146.jpg has the correct dimensions (227x227).
# The image Te-gl_0147.jpg has the correct dimensions (227x227).
# The image Te-gl_0148.jpg has the correct dimensions (227x227).
# The image Te-gl_0149.jpg has the correct dimensions (227x227).
# The image Te-gl_0150.jpg has the correct dimensions (227x227).
# The image Te-gl_0151.jpg has the correct dimensions (227x227).
# The image Te-gl_0152.jpg has the correct dimensions (227x227).
# The image Te-gl_0153.jpg has the correct dimensions (227x227).
# The image Te-gl_0154.jpg has the correct dimensions (227x227).
# The image Te-gl_0155.jpg has the correct dimensions (227x227).
# The image Te-gl_0156.jpg has the correct dimensions (227x227).
# The image Te-gl_0157.jpg has the correct dimensions (227x227).
# The image Te-gl_0158.jpg has the correct dimensions (227x227).
# The image Te-gl_0159.jpg has the correct dimensions (227x227).
# The image Te-gl_0160.jpg has the correct dimensions (227x227).
# The image Te-gl_0161.jpg has the correct dimensions (227x227).
# The image Te-gl_0162.jpg has the correct dimensions (227x227).
# The image Te-gl_0163.jpg has the correct dimensions (227x227).
# The image Te-gl_0164.jpg has the correct dimensions (227x227).
# The image Te-gl_0165.jpg has the correct dimensions (227x227).
# The image Te-gl_0166.jpg has the correct dimensions (227x227).
# The image Te-gl_0167.jpg has the correct dimensions (227x227).
# The image Te-gl_0168.jpg has the correct dimensions (227x227).
# The image Te-gl_0169.jpg has the correct dimensions (227x227).
# The image Te-gl_0170.jpg has the correct dimensions (227x227).
# The image Te-gl_0171.jpg has the correct dimensions (227x227).
# The image Te-gl_0172.jpg has the correct dimensions (227x227).
# The image Te-gl_0173.jpg has the correct dimensions (227x227).
# The image Te-gl_0174.jpg has the correct dimensions (227x227).
# The image Te-gl_0175.jpg has the correct dimensions (227x227).
# The image Te-gl_0176.jpg has the correct dimensions (227x227).
# The image Te-gl_0177.jpg has the correct dimensions (227x227).
# The image Te-gl_0178.jpg has the correct dimensions (227x227).
# The image Te-gl_0179.jpg has the correct dimensions (227x227).
# The image Te-gl_0180.jpg has the correct dimensions (227x227).
# The image Te-gl_0181.jpg has the correct dimensions (227x227).
# The image Te-gl_0182.jpg has the correct dimensions (227x227).
# The image Te-gl_0183.jpg has the correct dimensions (227x227).
# The image Te-gl_0184.jpg has the correct dimensions (227x227).
# The image Te-gl_0185.jpg has the correct dimensions (227x227).
# The image Te-gl_0186.jpg has the correct dimensions (227x227).
# The image Te-gl_0187.jpg has the correct dimensions (227x227).
# The image Te-gl_0188.jpg has the correct dimensions (227x227).
# The image Te-gl_0189.jpg has the correct dimensions (227x227).
# The image Te-gl_0190.jpg has the correct dimensions (227x227).
# The image Te-gl_0191.jpg has the correct dimensions (227x227).
# The image Te-gl_0192.jpg has the correct dimensions (227x227).
# The image Te-gl_0193.jpg has the correct dimensions (227x227).
# The image Te-gl_0194.jpg has the correct dimensions (227x227).
# The image Te-gl_0195.jpg has the correct dimensions (227x227).
# The image Te-gl_0196.jpg has the correct dimensions (227x227).
# The image Te-gl_0197.jpg has the correct dimensions (227x227).
# The image Te-gl_0198.jpg has the correct dimensions (227x227).
# The image Te-gl_0199.jpg has the correct dimensions (227x227).
# The image Te-gl_0200.jpg has the correct dimensions (227x227).
# The image Te-gl_0201.jpg has the correct dimensions (227x227).
# The image Te-gl_0202.jpg has the correct dimensions (227x227).
# The image Te-gl_0203.jpg has the correct dimensions (227x227).
# The image Te-gl_0204.jpg has the correct dimensions (227x227).
# The image Te-gl_0205.jpg has the correct dimensions (227x227).
# The image Te-gl_0206.jpg has the correct dimensions (227x227).
# The image Te-gl_0207.jpg has the correct dimensions (227x227).
# The image Te-gl_0208.jpg has the correct dimensions (227x227).
# The image Te-gl_0209.jpg has the correct dimensions (227x227).
# The image Te-gl_0210.jpg has the correct dimensions (227x227).
# The image Te-gl_0211.jpg has the correct dimensions (227x227).
# The image Te-gl_0212.jpg has the correct dimensions (227x227).
# The image Te-gl_0213.jpg has the correct dimensions (227x227).
# The image Te-gl_0214.jpg has the correct dimensions (227x227).
# The image Te-gl_0215.jpg has the correct dimensions (227x227).
# The image Te-gl_0216.jpg has the correct dimensions (227x227).
# The image Te-gl_0217.jpg has the correct dimensions (227x227).
# The image Te-gl_0218.jpg has the correct dimensions (227x227).
# The image Te-gl_0219.jpg has the correct dimensions (227x227).
# The image Te-gl_0220.jpg has the correct dimensions (227x227).
# The image Te-gl_0221.jpg has the correct dimensions (227x227).
# The image Te-gl_0222.jpg has the correct dimensions (227x227).
# The image Te-gl_0223.jpg has the correct dimensions (227x227).
# The image Te-gl_0224.jpg has the correct dimensions (227x227).
# The image Te-gl_0225.jpg has the correct dimensions (227x227).
# The image Te-gl_0226.jpg has the correct dimensions (227x227).
# The image Te-gl_0227.jpg has the correct dimensions (227x227).
# The image Te-gl_0228.jpg has the correct dimensions (227x227).
# The image Te-gl_0229.jpg has the correct dimensions (227x227).
# The image Te-gl_0230.jpg has the correct dimensions (227x227).
# The image Te-gl_0231.jpg has the correct dimensions (227x227).
# The image Te-gl_0232.jpg has the correct dimensions (227x227).
# The image Te-gl_0233.jpg has the correct dimensions (227x227).
# The image Te-gl_0234.jpg has the correct dimensions (227x227).
# The image Te-gl_0235.jpg has the correct dimensions (227x227).
# The image Te-gl_0236.jpg has the correct dimensions (227x227).
# The image Te-gl_0237.jpg has the correct dimensions (227x227).
# The image Te-gl_0238.jpg has the correct dimensions (227x227).
# The image Te-gl_0239.jpg has the correct dimensions (227x227).
# The image Te-gl_0240.jpg has the correct dimensions (227x227).
# The image Te-gl_0241.jpg has the correct dimensions (227x227).
# The image Te-gl_0242.jpg has the correct dimensions (227x227).
# The image Te-gl_0243.jpg has the correct dimensions (227x227).
# The image Te-gl_0244.jpg has the correct dimensions (227x227).
# The image Te-gl_0245.jpg has the correct dimensions (227x227).
# The image Te-gl_0246.jpg has the correct dimensions (227x227).
# The image Te-gl_0247.jpg has the correct dimensions (227x227).
# The image Te-gl_0248.jpg has the correct dimensions (227x227).
# The image Te-gl_0249.jpg has the correct dimensions (227x227).
# The image Te-gl_0250.jpg has the correct dimensions (227x227).
# The image Te-gl_0251.jpg has the correct dimensions (227x227).
# The image Te-gl_0252.jpg has the correct dimensions (227x227).
# The image Te-gl_0253.jpg has the correct dimensions (227x227).
# The image Te-gl_0254.jpg has the correct dimensions (227x227).
# The image Te-gl_0255.jpg has the correct dimensions (227x227).
# The image Te-gl_0256.jpg has the correct dimensions (227x227).
# The image Te-gl_0257.jpg has the correct dimensions (227x227).
# The image Te-gl_0258.jpg has the correct dimensions (227x227).
# The image Te-gl_0259.jpg has the correct dimensions (227x227).
# The image Te-gl_0260.jpg has the correct dimensions (227x227).
# The image Te-gl_0261.jpg has the correct dimensions (227x227).
# The image Te-gl_0262.jpg has the correct dimensions (227x227).
# The image Te-gl_0263.jpg has the correct dimensions (227x227).
# The image Te-gl_0264.jpg has the correct dimensions (227x227).
# The image Te-gl_0265.jpg has the correct dimensions (227x227).
# The image Te-gl_0266.jpg has the correct dimensions (227x227).
# The image Te-gl_0267.jpg has the correct dimensions (227x227).
# The image Te-gl_0268.jpg has the correct dimensions (227x227).
# The image Te-gl_0269.jpg has the correct dimensions (227x227).
# The image Te-gl_0270.jpg has the correct dimensions (227x227).
# The image Te-gl_0271.jpg has the correct dimensions (227x227).
# The image Te-gl_0272.jpg has the correct dimensions (227x227).
# The image Te-gl_0273.jpg has the correct dimensions (227x227).
# The image Te-gl_0274.jpg has the correct dimensions (227x227).
# The image Te-gl_0275.jpg has the correct dimensions (227x227).
# The image Te-gl_0276.jpg has the correct dimensions (227x227).
# The image Te-gl_0277.jpg has the correct dimensions (227x227).
# The image Te-gl_0278.jpg has the correct dimensions (227x227).
# The image Te-gl_0279.jpg has the correct dimensions (227x227).
# The image Te-gl_0280.jpg has the correct dimensions (227x227).
# The image Te-gl_0281.jpg has the correct dimensions (227x227).
# The image Te-gl_0282.jpg has the correct dimensions (227x227).
# The image Te-gl_0283.jpg has the correct dimensions (227x227).
# The image Te-gl_0284.jpg has the correct dimensions (227x227).
# The image Te-gl_0285.jpg has the correct dimensions (227x227).
# The image Te-gl_0286.jpg has the correct dimensions (227x227).
# The image Te-gl_0287.jpg has the correct dimensions (227x227).
# The image Te-gl_0288.jpg has the correct dimensions (227x227).
# The image Te-gl_0289.jpg has the correct dimensions (227x227).
# The image Te-gl_0290.jpg has the correct dimensions (227x227).
# The image Te-gl_0291.jpg has the correct dimensions (227x227).
# The image Te-gl_0292.jpg has the correct dimensions (227x227).
# The image Te-gl_0293.jpg has the correct dimensions (227x227).
# The image Te-gl_0294.jpg has the correct dimensions (227x227).
# The image Te-gl_0295.jpg has the correct dimensions (227x227).
# The image Te-gl_0296.jpg has the correct dimensions (227x227).
# The image Te-gl_0297.jpg has the correct dimensions (227x227).
# The image Te-gl_0298.jpg has the correct dimensions (227x227).
# The image Te-gl_0299.jpg has the correct dimensions (227x227).

# %%
curr=os.getcwd()
print(curr)
# Out:
# D:\RESEARCH D

# %%
import os

def check_folder_permissions(folder_path):
    if os.access(folder_path, os.R_OK):
        print(f"Read permission is granted on folder: {folder_path}")
    else:
        print(f"Read permission is NOT granted on folder: {folder_path}")

    if os.access(folder_path, os.W_OK):
        print(f"Write permission is granted on folder: {folder_path}")
    else:
        print(f"Write permission is NOT granted on folder: {folder_path}")

    if os.access(folder_path, os.X_OK):
        print(f"Execute permission is granted on folder: {folder_path}")
    else:
        print(f"Execute permission is NOT granted on folder: {folder_path}")

# Example usage
folder_path = "Testing"  # Specify the folder path you want to check permissions for
check_folder_permissions(folder_path)
# Out:
# Read permission is granted on folder: Testing
# Write permission is granted on folder: Testing
# Execute permission is granted on folder: Testing
